# %% [markdown]
# # Run individual simulation with customised parameters

# %%
from NetworkSim.simulation.simulator.base import BaseSimulator
from NetworkSim.architecture.setup.model import Model
from NetworkSim.architecture.base.network import Network

# %% [markdown]
# ## Create Network, Model and Simulator

# %%
model = Model(network=Network(num_nodes=100))
model.constants = {
    'speed': 2e8,                    # speed of light in fibre, in m/s
    'maximum_bit_rate': 100,         # system burst rate (maximum bit rate), in Gbit/s
    'average_bit_rate': 30,          # system average bit rate, in Gbit/s
    'data_guard_interval': 20,       # guard interval of data packets in ns
    'control_guard_interval': 0.14,  # guard interval of control packets in ns
    'tuning_time': 20                # tuning time of the receiver in ns
}
simulator = BaseSimulator(
    model=model,
    traffic_generation_method="poisson",
    transmitter_type="tunable",
    receiver_type="fixed"
)

# %% [markdown]
# ## Initialise and run simulation

# %%
simulator.initialise()
simulator.run()

# %% [markdown]
# ## Simulation summary

# %%
simulator.summary()
# Out:
#                                                    Value
# Simulation Parameter
# Total Number of Nodes                                100
# Transmitter Type                                 tunable
# Receiver Type                                      fixed
# Source Traffic Generation Method                 poisson
# Direction of Transmission                uni-directional
# Designed Average Data Rate (Gbit/s)                   30
# Designed Maximum Data Rate (Gbit/s)                  100
# Total Number of Data Packet Transmitted            59497
# Total Number of Transmission Error                     0
# Estimated Average Queueing Delay (ns)         378.203341
# Estimated Average Transfer Delay (ns)         818.203341
# Average Queueing Delay Latency (ns)           400.816983
# Average Transfer Delay Latency (ns)           841.279460
# Final Data Rate (Gbit/s)                     2974.973957
# Simulation Runtime (s)                         39.917015

# %% [markdown]
# ## Simulation plots

# %%
delay_and_throughput_plot = simulator.summary(output_format='plot')

# %%
latency_heatmap_plot = simulator.summary(summary_type='latency', output_format='plot')

# %%
node_latency_plot = simulator.summary(summary_type='latency', output_format='plot', node_id=0)

# %%
packet_count_heatmap_plot = simulator.summary(summary_type='count', output_format='plot')

# %%
from NetworkSim.simulation.tools.plot import *

# %%
batch_throughput_plot = plot_batch_throughput(simulator)
